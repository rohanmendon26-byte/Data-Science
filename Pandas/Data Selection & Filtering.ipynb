# %%
 import pandas as pd

df=pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                     Film  Year            Genre  \
# 0       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 1          Salman Khan                   Dangal  2016           Action
# 2           Aamir Khan                   Dangal  2016        Biography
# 3        Ranbir Kapoor               Brahmastra  2022          Fantasy
# 4        Ranveer Singh                Padmaavat  2018         Thriller
# 5   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 6        Rajkummar Rao                    Stree  2018    Horror Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Akshay Kumar               Good Newwz  2019           Comedy
# 9        Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri:The Surgical Strike  2019           Action
#
#     BoxOffice  IMDb
# 0        1050   7.2
# ...

# %%
df["Actor"]
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
type(df["IMDb"])
# Out:
# pandas.core.series.Series

# %%
df[["Actor","Film"]]
# Out:
#                  Actor                     Film
# 0       Shah Rukh Khan          Tiger Zinda Hai
# 1          Salman Khan                   Dangal
# 2           Aamir Khan                   Dangal
# 3        Ranbir Kapoor               Brahmastra
# 4        Ranveer Singh                Padmaavat
# 5   Ayushmann Khurrana                Andhadhun
# 6        Rajkummar Rao                    Stree
# 7       Hrithik Roshan                      War
# 8         Akshay Kumar               Good Newwz
# 9        Kartik Aaryan          Bhool Bhulaiyaa
# 10        Varun Dhawan         Badrinath Ki Dul
# 11       Vicky Kaushal  Uri:The Surgical Strike

# %%
df.loc[0]
# Out:
# Actor         Shah Rukh Khan
# Film         Tiger Zinda Hai
# Year                    2023
# Genre                 Action
# BoxOffice               1050
# IMDb                     7.2
# Name: 0, dtype: object

# %%
df.loc[5]
# Out:
# Actor        Ayushmann Khurrana
# Film                  Andhadhun
# Year                       2018
# Genre             Horror Comedy
# BoxOffice                   180
# IMDb                        7.5
# Name: 5, dtype: object

# %%
df.iloc[0]
# Out:
# Actor         Shah Rukh Khan
# Film         Tiger Zinda Hai
# Year                    2023
# Genre                 Action
# BoxOffice               1050
# IMDb                     7.2
# Name: 0, dtype: object

# %%
df.loc[7,"Actor"]
# Out:
# 'Hrithik Roshan'

# %%
df.iloc[0,1]
# Out:
# 'Tiger Zinda Hai'

# %%
df.loc[0:2,["Year","Genre"]]
# Out:
#    Year      Genre
# 0  2023     Action
# 1  2016     Action
# 2  2016  Biography

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,1]
# Out:
# 'Tiger Zinda Hai'

# %%
df[df["IMDb"]>6]
# Out:
#                  Actor                     Film  Year            Genre  \
# 0       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 2           Aamir Khan                   Dangal  2016        Biography
# 4        Ranveer Singh                Padmaavat  2018         Thriller
# 5   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 6        Rajkummar Rao                    Stree  2018    Horror Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Akshay Kumar               Good Newwz  2019           Comedy
# 10        Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri:The Surgical Strike  2019           Action
#
#     BoxOffice  IMDb
# 0        1050   7.2
# 2        2024   8.4
# 4         111   8.3
# 5         180   7.5
# 6         180   7.5
# 7         475   6.5
# 8         318   7.0
# 10        201   6.1
# 11        342   8.2

# %%
df[(df["Year"]>2019)|(df["IMDb"]>9)]
# Out:
#             Actor             Film  Year          Genre  BoxOffice  IMDb
# 0  Shah Rukh Khan  Tiger Zinda Hai  2023         Action       1050   7.2
# 3   Ranbir Kapoor       Brahmastra  2022        Fantasy        431   5.6
# 9   Kartik Aaryan  Bhool Bhulaiyaa  2022  Horror Comedy        266   5.9

# %%
df.query("Year > 2015")
# Out:
#                  Actor                     Film  Year            Genre  \
# 0       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 1          Salman Khan                   Dangal  2016           Action
# 2           Aamir Khan                   Dangal  2016        Biography
# 3        Ranbir Kapoor               Brahmastra  2022          Fantasy
# 4        Ranveer Singh                Padmaavat  2018         Thriller
# 5   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 6        Rajkummar Rao                    Stree  2018    Horror Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Akshay Kumar               Good Newwz  2019           Comedy
# 9        Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri:The Surgical Strike  2019           Action
#
#     BoxOffice  IMDb
# 0        1050   7.2
# ...
