# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                     Film  Year            Genre  \
# 0       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 1          Salman Khan                   Dangal  2016           Action
# 2           Aamir Khan                   Dangal  2016        Biography
# 3        Ranbir Kapoor               Brahmastra  2022          Fantasy
# 4        Ranveer Singh                Padmaavat  2018         Thriller
# 5   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 6        Rajkummar Rao                    Stree  2018    Horror Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Akshay Kumar               Good Newwz  2019           Comedy
# 9        Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri:The Surgical Strike  2019           Action
#
#     BoxOffice  IMDb
# 0        1050   7.2
# ...

# %%
df.sort_values("IMDb",ascending=False)
# Out:
#                  Actor                     Film  Year            Genre  \
# 0           Aamir Khan                   Dangal  2016        Biography
# 1        Ranveer Singh                Padmaavat  2018         Thriller
# 2        Vicky Kaushal  Uri:The Surgical Strike  2019           Action
# 3        Rajkummar Rao                    Stree  2018    Horror Comedy
# 4   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 5       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 6         Akshay Kumar               Good Newwz  2019           Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 9          Salman Khan                   Dangal  2016           Action
# 10       Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 11       Ranbir Kapoor               Brahmastra  2022          Fantasy
#
#     BoxOffice  IMDb
# 0        2024   8.4
# ...

# %%
df.reset_index()
# Out:
#     index               Actor                     Film  Year            Genre  \
# 0       0          Aamir Khan                   Dangal  2016        Biography
# 1       1       Ranveer Singh                Padmaavat  2018         Thriller
# 2       2       Vicky Kaushal  Uri:The Surgical Strike  2019           Action
# 3       3       Rajkummar Rao                    Stree  2018    Horror Comedy
# 4       4  Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 5       5      Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 6       6        Akshay Kumar               Good Newwz  2019           Comedy
# 7       7      Hrithik Roshan                      War  2019           Action
# 8       8        Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 9       9         Salman Khan                   Dangal  2016           Action
# 10     10       Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                  Actor                     Film  Year            Genre  \
# 0           Aamir Khan                   Dangal  2016        Biography
# 1        Ranveer Singh                Padmaavat  2018         Thriller
# 2        Vicky Kaushal  Uri:The Surgical Strike  2019           Action
# 3        Rajkummar Rao                    Stree  2018    Horror Comedy
# 4   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 5       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 6         Akshay Kumar               Good Newwz  2019           Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 9          Salman Khan                   Dangal  2016           Action
# 10       Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 11       Ranbir Kapoor               Brahmastra  2022          Fantasy
#
#     BoxOffice  IMDb
# 0        2024   8.4
# ...

# %%
df
# Out:
#                  Actor                     Film  Year            Genre  \
# 0           Aamir Khan                   Dangal  2016        Biography
# 1        Ranveer Singh                Padmaavat  2018         Thriller
# 2        Vicky Kaushal  Uri:The Surgical Strike  2019           Action
# 3        Rajkummar Rao                    Stree  2018    Horror Comedy
# 4   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 5       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 6         Akshay Kumar               Good Newwz  2019           Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 9          Salman Khan                   Dangal  2016           Action
# 10       Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 11       Ranbir Kapoor               Brahmastra  2022          Fantasy
#
#     BoxOffice  IMDb
# 0        2024   8.4
# ...

# %%
df["Rank"] = df["IMDb"].rank()

# %%
df
# Out:
#                  Actor                     Film  Year            Genre  \
# 0           Aamir Khan                   Dangal  2016        Biography
# 1        Ranveer Singh                Padmaavat  2018         Thriller
# 2        Vicky Kaushal  Uri:The Surgical Strike  2019           Action
# 3        Rajkummar Rao                    Stree  2018    Horror Comedy
# 4   Ayushmann Khurrana                Andhadhun  2018    Horror Comedy
# 5       Shah Rukh Khan          Tiger Zinda Hai  2023           Action
# 6         Akshay Kumar               Good Newwz  2019           Comedy
# 7       Hrithik Roshan                      War  2019           Action
# 8         Varun Dhawan         Badrinath Ki Dul  2017  Romantic Comedy
# 9          Salman Khan                   Dangal  2016           Action
# 10       Kartik Aaryan          Bhool Bhulaiyaa  2022    Horror Comedy
# 11       Ranbir Kapoor               Brahmastra  2022          Fantasy
#
#     BoxOffice  IMDb  Rank
# ...

# %%
df.rename(columns={"Actor": "Act"}, inplace=True)
