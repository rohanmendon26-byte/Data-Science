# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
student={
    "name":"Alice",
    "age":25,
    "grade":"A"
}

# %%
student["name"]
# Out:
# 'Alice'

# %%
student["age"]
# Out:
# 25

# %%
r=student.get("name4")

# %%
r

# %%
print(r)
# Out:
# None

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"]=57

# %%
student["age"]
# Out:
# 57

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 57, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 57), ('grade', 'A')])

# %%
student.update({"name":"Harry"})

# %%
student
# Out:
# {'name': 'Harry', 'age': 57, 'grade': 'A'}

# %%
student.update({"name":"Ruchika","language":"Python"})

# %%
student
# Out:
# {'name': 'Ruchika', 'age': 57, 'grade': 'A', 'language': 'Python'}

# %%
d = {}

d["name"] = "Rohan"

# %%
d.setdefault("name", "Rohan")
# Out:
# 'Rohan'

# %%
print(d)
# Out:
# {'name': 'Rohan'}

# %%
d = {
    "name": "Rohan"
}

x = d.setdefault("name", "Rahul")

print(x)
print(d)
# Out:
# Rohan
# {'name': 'Rohan'}
