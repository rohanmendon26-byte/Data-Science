# %%
s={4,3,6,2,4,4}

# %%
s
# Out:
# {2, 3, 4, 6}

# %%
 s.remove(4)

# %%
s
# Out:
# {2, 3, 6}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {3, 6}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
set1={1,2,3,4}
set2={3,4,5,6}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub={1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
