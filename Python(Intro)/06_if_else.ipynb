# %%
case=300

# %%
match case:
     case 200:
        print("done")
     case 300:
         print("not done")
# Out:
# not done

# %%
a="Rohan"
b=20
print(f"My name is {a} and my age is {b}")
# Out:
# My name is Rohan and my age is 20

# %%
print(f"{'Python':<10}")
print(f"{'Python':>10}")
print(f"{'Python':^10}")
# Out:
# Python
#     Python
#   Python

# %%
l=[3,4,23,5]

# %%
l[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 l[6]
#
# IndexError: list index out of range

# %%
l[2]
# Out:
# 23

# %%
l[2]=5

# %%
l
# Out:
# [3, 4, 5, 5]

# %%
l.append(9)

# %%
l
# Out:
# [3, 4, 5, 5, 9]

# %%
l2=[5,7]

# %%
l.extend(l2)

# %%
l
# Out:
# [3, 4, 5, 5, 9, 5, 7]

# %%
l.insert(0,23)

# %%
l
# Out:
# [23, 3, 4, 5, 5, 9, 5, 7]

# %%
l.pop(4)
# Out:
# 5

# %%
l.index(23)
# Out:
# 0

# %%
l.count(5)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [3, 4, 5, 5, 7, 9, 23]

# %%
sorted(l)
# Out:
# [3, 4, 5, 5, 7, 9, 23]

# %%
newl=[2,6,1,21,6]

# %% [raw]
# sorted(newl)

# %%
newl
# Out:
# [2, 6, 1, 21, 6]

# %%
newl.reverse()

# %%
newl
# Out:
# [6, 21, 1, 6, 2]

# %%
s="rahul,rohan,deepak"
s.split(",")
# Out:
# ['rahul', 'rohan', 'deepak']
