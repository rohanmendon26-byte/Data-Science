# %%
result=10+2*3*3

# %%
result
# Out:
# 28

# %%
l=[3,4,5,7]
for i in l:
    print(i)
# Out:
# 3
# 4
# 5
# 7

# %%
for i in range(5,11):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
count=0
while count<3:
    print(count)
    count+=1
# Out:
# 0
# 1
# 2

# %%
e=()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
t=(5,6,7,8)

# %%
t
# Out:
# (5, 6, 7, 8)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 6

# %%
l=(1,2,3,3,3,4)

# %%
index(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 index(3)
#
# NameError: name 'index' is not defined

# %%
l.index(3)
# Out:
# 2

# %%
l.count(3)
# Out:
# 3

# %%
l.count(2)
# Out:
# 1
