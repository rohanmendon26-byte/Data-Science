# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
str="Harry"

# %%
print(str)
# Out:
# Harry

# %%
#this is a comment

# %%
print(type(str))
# Out:
# <class 'str'>

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a="Rohan"
b=" mendon"
print(a+b)
# Out:
# Rohan mendon

# %%
a="12"
b="12"
int(a)+int(b)
# Out:
# 24
